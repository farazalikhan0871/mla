# %%
import random

POPULATION_SIZE = 100
GENES = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ 1234567890, .-;:_!\"#%&/()=?@${[]}"
TARGET = "I Love Ironman"

def random_num(start, end):
    return random.randint(start, end)

def mutated_genes():
    return random.choice(GENES)

def create_gnome():
    return ''.join(mutated_genes() for _ in range(len(TARGET)))

class Individual:
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    def mate(self, par2):
        child_chromosome = ''
        for i in range(len(self.chromosome)):
            p = random.random()
            if p < 0.45:
                child_chromosome += self.chromosome[i]
            elif p < 0.90:
                child_chromosome += par2.chromosome[i]
            else:
                child_chromosome += mutated_genes()                                                                                                               
        return Individual(child_chromosome)

    def cal_fitness(self):
        return sum(1 for c1, c2 in zip(self.chromosome, TARGET) if c1 != c2)

def main():
    generation = 0
    population = [Individual(create_gnome()) for _ in range(POPULATION_SIZE)]
    found = False

    while not found:
        population.sort(key=lambda x: x.fitness)

        if population[0].fitness <= 0:
            found = True
            break

        new_generation = population[:10]

        for _ in range(90):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            offspring = parent1.mate(parent2)
            new_generation.append(offspring)

        population = new_generation

        print(f"Generation: {generation}\tString: {population[0].chromosome}\tFitness: {population[0].fitness}")
        generation += 1

    print(f"Generation: {generation}\tString: {population[0].chromosome}\tFitness: {population[0].fitness}")

if __name__ == "__main__":
    main()
# Out:
# Generation: 0	String: c6%l ,sS"8 3copD-=kl	Fitness: 18
# Generation: 1	String: c6%l ,sS"8 3copD-=kl	Fitness: 18
# Generation: 2	String: #$(ka(Y_ke,.j%=#vekM	Fitness: 17
# Generation: 3	String: #$(ka(Y_ke,.j%=#vekM	Fitness: 17
# Generation: 4	String:  @&:oi w"8 U3o@[gekR	Fitness: 16
# Generation: 5	String: I@lo)x{Ve"oESL)Geak)	Fitness: 13
# Generation: 6	String: I@lo)x{Ve"oESL)Geak)	Fitness: 13
# Generation: 7	String: I@lo)x{Ve"oESL)Geak)	Fitness: 13
# Generation: 8	String: I@lo[i=VeM;EMo@Gerk%	Fitness: 12
# Generation: 9	String: I@lo[i=VeM;EMo@Gerk%	Fitness: 12
# Generation: 10	String: I}%o5JoheekUSo=Geeke	Fitness: 10
# Generation: 11	String: I}%o5JoheekUSo=Geeke	Fitness: 10
# Generation: 12	String: I}%o5JoheekUSo=Geeke	Fitness: 10
# Generation: 13	String: I}%o[JKGeekF1o;Geek?	Fitness: 9
# Generation: 14	String: I}%o[JKGeekF1o;Geek?	Fitness: 9
# Generation: 15	String: I@%o5i7Geeka4oiGeeks	Fitness: 8
# Generation: 16	String: I@%o5i7Geeka4oiGeeks	Fitness: 8
# Generation: 17	String: Iilo5J{GeekF4o=Geeks	Fitness: 7
# Generation: 18	String: Iilo5J{GeekF4o=Geeks	Fitness: 7
# Generation: 19	String: Iilo5J{GeekF4o=Geeks	Fitness: 7
# Generation: 20	String: Iilo5J{GeekF4o=Geeks	Fitness: 7
# Generation: 21	String: Iilo5J{GeekF4o=Geeks	Fitness: 7
# Generation: 22	String: I}lovJqGeekFjo@Geeks	Fitness: 6
# Generation: 23	String: I}lovJqGeekFjo@Geeks	Fitness: 6
# Generation: 24	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 25	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 26	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 27	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 28	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 29	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 30	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 31	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 32	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 33	String: I lovx7Geekajo@Geeks	Fitness: 5
# Generation: 34	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 35	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 36	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 37	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 38	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 39	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 40	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 41	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 42	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 43	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 44	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 45	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 46	String: I love$GeekdJoxGeeks	Fitness: 4
# Generation: 47	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 48	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 49	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 50	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 51	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 52	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 53	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 54	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 55	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 56	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 57	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 58	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 59	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 60	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 61	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 62	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 63	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 64	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 65	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 66	String: I love7GeekafoKGeeks	Fitness: 3
# Generation: 67	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 68	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 69	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 70	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 71	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 72	String: I love Geek2foKGeeks	Fitness: 2
# Generation: 73	String: I love GeekoforGeeks	Fitness: 1
# Generation: 74	String: I love GeekoforGeeks	Fitness: 1
# Generation: 75	String: I love GeekoforGeeks	Fitness: 1
# Generation: 76	String: I love GeekoforGeeks	Fitness: 1
# Generation: 77	String: I love GeekoforGeeks	Fitness: 1
# Generation: 78	String: I love GeekoforGeeks	Fitness: 1
# Generation: 79	String: I love GeekoforGeeks	Fitness: 1
# Generation: 80	String: I love GeekoforGeeks	Fitness: 1
# Generation: 81	String: I love GeekoforGeeks	Fitness: 1
# Generation: 82	String: I love GeekoforGeeks	Fitness: 1
# Generation: 83	String: I love GeekoforGeeks	Fitness: 1
# Generation: 84	String: I love GeekoforGeeks	Fitness: 1
# Generation: 85	String: I love GeekoforGeeks	Fitness: 1
# Generation: 86	String: I love GeekoforGeeks	Fitness: 1
# Generation: 87	String: I love GeekoforGeeks	Fitness: 1
# Generation: 88	String: I love GeekoforGeeks	Fitness: 1
# Generation: 89	String: I love GeekoforGeeks	Fitness: 1
# Generation: 90	String: I love GeekoforGeeks	Fitness: 1
# Generation: 91	String: I love GeekoforGeeks	Fitness: 1
# Generation: 92	String: I love GeekoforGeeks	Fitness: 1
# Generation: 93	String: I love GeekoforGeeks	Fitness: 1
# Generation: 94	String: I love GeekoforGeeks	Fitness: 1
# Generation: 95	String: I love GeekoforGeeks	Fitness: 1
# Generation: 96	String: I love GeekoforGeeks	Fitness: 1
# Generation: 97	String: I love GeekoforGeeks	Fitness: 1
# Generation: 98	String: I love GeeksforGeeks	Fitness: 0
